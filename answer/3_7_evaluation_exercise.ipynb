# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/python_ml_dl2/blob/main/answer/3_7_evaluation_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 문제1
# 다음 데이터를 사용하여 정확도, 정밀도, 재현율, f1 스코어, 혼동행렬을 출력하는 코드를 작성하시오.

# %%
# 예시 데이터
y_true = [0, 1, 0, 1, 0, 1, 1, 0, 1, 0]
y_pred = [0, 1, 0, 0, 0, 1, 1, 0, 1, 1]
y_score = [0.1, 0.9, 0.2, 0.4, 0.3, 0.8, 0.7, 0.2, 0.9, 0.85]

# %%
# 코드 작성

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# 정확도
accuracy = accuracy_score(y_true, y_pred)

# 정밀도
precision = precision_score(y_true, y_pred)

# 재현율
recall = recall_score(y_true, y_pred)

# F1 스코어
f1 = f1_score(y_true, y_pred)

# 혼동행렬
cm = confusion_matrix(y_true, y_pred)

# 출력
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8
# Precision: 0.8
# Recall: 0.8
# F1-Score: 0.8
# Confusion Matrix:
# [[4 1]
#  [1 4]]

# %% [markdown]
# #문제2
# 다음의 로지스틱 회귀 모델의 훈련 결과를 ROC 커브로 시각화하여 표시하시오.

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

# 예시 데이터 생성
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 로지스틱 회귀 모델 훈련
model = LogisticRegression()
model.fit(X_train, y_train)

# 예측 확률 계산
y_score = model.predict_proba(X_test)[:, 1]  # 양성 클래스의 확률

# %%
# 코드 작성

from sklearn.metrics import roc_curve, auc

# ROC 커브 계산
fpr, tpr, thresholds = roc_curve(y_test, y_score)

# AUC 계산
roc_auc = auc(fpr, tpr)

# ROC 커브 시각화
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # 랜덤 예측선을 추가
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# # 문제3
# 주어진 데이터에 대해 MSE, RMSE, 결정계수 값을 계산하여 출력하시오.

# %%
y_true = [0, 1, 2, 3, 4, 5]
y_pred = [0, 1.2, 3.3, 3.9, 3.8, 5.2]

# %%
# 코드 작성

from sklearn.metrics import mean_squared_error

# MSE 연산 결과
mean_squared_error(y_true, y_pred)
# Out:
# 0.43666666666666654

# %%
import numpy as np
# RMSE 연산 결과
np.sqrt(mean_squared_error(y_true, y_pred))
# Out:
# 0.6608075867199669

# %%
from sklearn.metrics import r2_score
# 결정계수 연산 결과

r2_score(y_true, y_pred)
# Out:
# 0.8502857142857143
