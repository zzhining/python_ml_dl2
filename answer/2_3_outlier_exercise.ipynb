# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/python_ml_dl2/blob/main/answer/2_3_outlier_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris

# 데이터 로딩
iris = load_iris()

# 로딩한 데이터를 데이터 프레임으로 생성
df = pd.DataFrame(data=iris.data)
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %% [markdown]
# # 문제1
# IQR기반 이상치를 판단하여 이상치로 판단된 경우 NaN으로 대체하는 함수를 작성하시오.

# %%
def detect_outliers(df):
    # 완성하시오
    return df

# 이상치 처리 결과
df_cleaned = detect_outliers(df)

# %% [markdown]
# <힌트>
# ```
# quantile()
# ```

# %%
def detect_outliers(df):
    # 각 컬럼에 대해 IQR 계산
    for col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # 이상치 처리: 이상치가 있으면 해당 값들을 NaN으로 대체
        df[col] = df[col].apply(lambda x: x if lower_bound <= x <= upper_bound else None)

    return df

# 이상치 처리 결과
df_cleaned = detect_outliers(df)

# %% [markdown]
# # 문제2
# Z-score기반으로 임계치(3)을 벗어날 경우, NaN으로 대체하는 함수를 작성하시오.

# %%
def detect_outliers_zscore(df, threshold=3):
    # 완성하시오
    return df

# 이상치 처리 결과
df_cleaned = detect_outliers_zscore(df)

# %% [markdown]
# <힌트>
# ```
# mean()
# std()
# ```

# %%
def detect_outliers_zscore(df, threshold=3):
    for col in df.columns:
        mean = df[col].mean()
        std_dev = df[col].std()

        # Z-Score 계산
        z_scores = (df[col] - mean) / std_dev

        # 이상치 처리: Z-Score가 threshold보다 크거나 작은 값들을 NaN으로 대체
        df[col] = df[col].apply(lambda x: x if abs((x - mean) / std_dev) <= threshold else None)

    return df

# 이상치 처리
df_cleaned = detect_outliers_zscore(df)
